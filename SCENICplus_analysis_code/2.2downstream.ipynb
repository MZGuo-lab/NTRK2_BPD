# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import sys
import os
_stderr = sys.stderr
null = open(os.devnull,'wb')

import dill

import mudata

# %%
scplus_mdata = mudata.read("./outs/scplus_pipeline/Snakemake/outs/scplusmdata.h5mu")

# %% [raw]
# wnn_emb = pd.read_csv('./outs/scplus_pipeline/Snakemake/outs/embeddings_wnn.csv')
# wnn_emb.index = wnn_emb.index.astype(str) + "__BPD_gCAP"
#
# scplus_mdata.mod["scRNA_counts"].obsm["X_wnn_umap"] = (
#     wnn_emb.reindex(scplus_mdata.mod["scRNA_counts"].obs_names)
#            .to_numpy(dtype="float32")
# )

# %%
import anndata as ad
import numpy as np, pandas as pd
from scipy import sparse

cistrome_direct = ad.read_h5ad('outs/scplus_pipeline/Snakemake/outs/cistromes_direct.h5ad')

regions = np.asarray(cistrome_direct.obs_names)  # RE IDs
tfs     = np.asarray(cistrome_direct.var_names)  # TF names
X = cistrome_direct.X

if sparse.issparse(X):
    coo = X.tocoo(copy=False)
    tf_re = pd.DataFrame({"TF": tfs[coo.col], "region": regions[coo.row]})
else:
    arr = np.asarray(X)
    r, c = np.where(arr != 0)
    tf_re = pd.DataFrame({"TF": tfs[c], "region": regions[r]})

tf_re.drop_duplicates().to_csv("outs/scplus_pipeline/Snakemake/outs/cistromes_direct.TF_RE.tsv", sep="\t", index=False)

# %%
scplus_mdata.uns["extended_e_regulon_metadata"]

# %% [markdown]
# # eRegulon dimensionality reduction

# %%
import scanpy as sc
import anndata
eRegulon_gene_AUC = anndata.concat(
    [scplus_mdata["direct_gene_based_AUC"], scplus_mdata["extended_gene_based_AUC"]],
    axis = 1,
)

# %%
eRegulon_gene_AUC.obs = scplus_mdata.obs.loc[eRegulon_gene_AUC.obs_names]

# %%
sc.pp.neighbors(eRegulon_gene_AUC, use_rep = "X")

# %%
sc.pl.umap(eRegulon_gene_AUC, color = "scRNA_counts:celltype")

# %%
sc.pl.umap(eRegulon_gene_AUC, color = "scRNA_counts:celltype",legend_loc = 'on data',legend_fontsize = 8,legend_fontweight= 'normal')

# %%
sc.pl.umap(eRegulon_gene_AUC, color = "scRNA_counts:Celltype2",legend_loc = 'on data',legend_fontsize = 8,legend_fontweight= 'normal')

# %% [markdown]
# # eRegulon specificity score

# %%
from scenicplus.RSS import (regulon_specificity_scores, plot_rss)

# %%
rss = regulon_specificity_scores(
    scplus_mudata = scplus_mdata,
    variable = "scRNA_counts:celltype",
    modalities = ["direct_gene_based_AUC", "extended_gene_based_AUC"]
)

# %%
plot_rss(
    data_matrix = rss,
    top_n = 5,
    num_columns = 5
)

# %% [markdown]
# # Plot eRegulon enrichment scores

# %%
sc.pl.umap(eRegulon_gene_AUC, color = list(set([x for xs in [rss.loc[ct].sort_values(ascending=False,)[0:2].index for ct in rss.index] for x in xs ])))

# %% [markdown]
# # Heatmap dotplot

# %%
from scenicplus.plotting.dotplot import heatmap_dotplot

# %%
filtered_df = pd.read_csv('outs/scplus_pipeline/Snakemake/outs/eRegulon_direct_filtered.tsv',sep='\t')
mask = (filtered_df["triplet_pass"] == True) & (filtered_df["symbols"].eq("+/+"))
subset_df = filtered_df.loc[mask].copy()
unique_features = subset_df['eRegulon_name'].unique()
group_order = [
    "gCap-C2_BPD", "gCap-C2_Control",
    "gCap-C1_BPD", "gCap-C1_Control",
    "aCap_BPD", "aCap_Control",
    "Venous_BPD", "Venous_Control",
    "SystemicVenous_BPD", "SystemicVenous_Control",
    "Lymphatics_BPD", "Lymphatics_Control",
    "Arterial_BPD", "Arterial_Control",
]
group_order_rev = list(reversed(group_order))

dotplot= heatmap_dotplot(
    scplus_mudata = scplus_mdata,
    color_modality = "direct_gene_based_AUC",
    size_modality = "direct_region_based_AUC",
    group_variable = "scRNA_counts:celltype",
    eRegulon_metadata_key = "direct_e_regulon_metadata",
    color_feature_key = "Gene_signature_name",
    size_feature_key = "Region_signature_name",
    feature_name_key = "eRegulon_name",
    sort_data_by = "direct_gene_based_AUC",
    #sort_data_by=None,
    orientation = "horizontal",
    subset_feature_names = unique_features,
    group_variable_order= group_order_rev,
)

from plotnine import theme, element_text

dotplot += theme(
    axis_text_x=element_text(size=15),
    axis_text_y=element_text(size=15)
)
dotplot += theme(
    axis_text_x=element_text(size=12, angle=90, ha='center')
)
dotplot

dotplot.save("outs/scplus_pipeline/Snakemake/outs/dotplot_heatmap_positive.png", dpi=600, width=22, height=6.5, units="in", verbose=False)



fig = dotplot.draw()                         # renders to a Matplotlib Figure
ax = fig.axes[0]

# If features are on the X axis (orientation="horizontal", as in your code):
x_labels = [t.get_text() for t in ax.get_xticklabels()]

# Save for R
with open("outs/scplus_pipeline/Snakemake/outs/eregulon_labels.txt", "w") as f:
    for lab in x_labels:
        f.write(lab + "\n")

# %%
import mudata
import os
scplus_outdir = "outs/scplus_pipeline/Snakemake/outs/"

scplus_mdata = mudata.read(os.path.join(scplus_outdir, 'scplusmdata.h5mu'))

# %%
scplus_mdata.obs['scRNA_counts:celltype'] = scplus_mdata.obs.index.str.rsplit('_', n=1).str[0]
scplus_mdata.obs['scATAC_counts:celltype'] = scplus_mdata.obs.index.str.rsplit('_', n=1).str[0]

# %%
scplus_mdata.obs
# Out:
#                                                 scRNA_counts:orig.ident  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP           D253_Multiome
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP           D253_Multiome
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP           D253_Multiome
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP           D253_Multiome
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP           D253_Multiome
# ...                                                                 ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP           D253_Multiome
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP           D253_Multiome
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP           D111_Multiome
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP           D111_Multiome
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP           D111_Multiome
#
#                                                  scRNA_counts:nCount_RNA  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP                   3593.0
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP                   1667.0
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP                   3320.0
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP                   2636.0
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP                   1997.0
# ...                                                                  ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP                   1138.0
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP                   3884.0
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP                   5251.0
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP                   2275.0
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP                   3491.0
#
#                                                  scRNA_counts:nFeature_RNA  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP                       1761
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP                        971
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP                       1814
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP                       1554
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP                       1094
# ...                                                                    ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP                        739
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP                       1968
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP                       1874
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP                       1398
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP                       1553
#
#                                                  scRNA_counts:nCount_ATAC  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP                    6379.0
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP                    2676.0
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP                    6499.0
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP                    2650.0
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP                    1866.0
# ...                                                                   ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP                    2652.0
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP                    2105.0
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP                    6145.0
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP                    4891.0
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP                    4361.0
#
#                                                  scRNA_counts:nFeature_ATAC  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP                        5599
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP                        2479
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP                        5639
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP                        2457
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP                        1689
# ...                                                                     ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP                        2351
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP                        1997
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP                        5312
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP                        4284
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP                        3781
#
#                                                 scRNA_counts:barcode  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP   GACCTTTGTTGCACGG-1
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP   TGAGCACGTGCGCGTA-1
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP   TACCGTTGTGGGTGAA-1
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP   TTGGGTTAGCTCAAAC-1
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP   TAAGTAGCAGCCTGCA-1
# ...                                                              ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP   CCGATGCAGCTCCTAC-1
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP   TGGCTAAGTAATCCCT-1
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP   TGCATCCTCAGGCTAT-1
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP   ACGGTACGTGATTTGG-1
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP   TCATAACCATAAACCT-1
#
#                                                 scRNA_counts:gex_barcode  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP       GACCTTTGTTGCACGG-1
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP       TGAGCACGTGCGCGTA-1
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP       TACCGTTGTGGGTGAA-1
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP       TTGGGTTAGCTCAAAC-1
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP       TAAGTAGCAGCCTGCA-1
# ...                                                                  ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP       CCGATGCAGCTCCTAC-1
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP       TGGCTAAGTAATCCCT-1
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP       TGCATCCTCAGGCTAT-1
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP       ACGGTACGTGATTTGG-1
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP       TCATAACCATAAACCT-1
#
#                                                 scRNA_counts:atac_barcode  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP        GGTGCATCAGGTCAAC-1
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP        TAAACCGCAAGTGCCG-1
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP        CGGTGTGCAAGTATCG-1
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP        GTGTGAGTCGGTAATA-1
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP        GTTAACCGTTTCTAAG-1
# ...                                                                   ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP        GTCGGTTTCTTAGCCA-1
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP        CTTCCAGCAGCCTGAG-1
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP        CGCTTTAAGGCACGTA-1
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP        AGCTAATCACTAAGGC-1
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP        GATGGACGTGCACCAC-1
#
#                                                  scRNA_counts:is_cell  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP                     1
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP                     1
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP                     1
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP                     1
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP                     1
# ...                                                               ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP                     1
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP                     1
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP                     1
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP                     1
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP                     1
#
#                                                  scRNA_counts:excluded_reason  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP                             0
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP                             0
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP                             0
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP                             0
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP                             0
# ...                                                                       ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP                             0
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP                             0
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP                             0
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP                             0
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP                             0
#
#                                                  ...  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP  ...
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP  ...
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP  ...
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP  ...
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP  ...
# ...                                              ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP  ...
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP  ...
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP  ...
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP  ...
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP  ...
#
#                                                  scATAC_counts:wsnn_res.10  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP                         43
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP                         37
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP                         20
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP                         12
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP                         14
# ...                                                                    ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP                         25
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP                         37
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP                         45
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP                         20
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP                         18
#
#                                                  scATAC_counts:Celltype_4  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP                      CAP1
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP                      CAP2
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP                      CAP1
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP                      CAP2
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP                      CAP1
# ...                                                                   ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP                      CAP2
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP                      CAP2
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP                      CAP2
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP                      CAP1
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP                      CAP1
#
#                                                  scATAC_counts:Cluster  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP                      1
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP                      8
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP                      3
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP                      8
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP                      4
# ...                                                                ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP                      8
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP                      8
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP                      8
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP                      3
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP                      6
#
#                                                  scATAC_counts:Celltype  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP                       1
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP                       2
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP                       1
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP                       2
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP                       1
# ...                                                                 ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP                       2
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP                       2
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP                       2
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP                       1
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP                       1
#
#                                                  scATAC_counts:Group  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP            D253_CAP1
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP            D253_CAP2
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP            D253_CAP1
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP            D253_CAP2
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP            D253_CAP1
# ...                                                              ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP            D253_CAP2
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP            D253_CAP2
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP            D111_CAP2
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP            D111_CAP1
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP            D111_CAP1
#
#                                                                       scATAC_counts:celltype  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP  D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP  D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP  D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP  D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP  D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control
# ...                                                                                      ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP  D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP  D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP  D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP  D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP  D111_Multiome_TCATAACCATAAACCT-1-NL_Control
#
#                                                  scATAC_counts:sample_id  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP           NL_Control_CAP
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP           NL_Control_CAP
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP           NL_Control_CAP
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP           NL_Control_CAP
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP           NL_Control_CAP
# ...                                                                  ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP           NL_Control_CAP
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP           NL_Control_CAP
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP           NL_Control_CAP
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP           NL_Control_CAP
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP           NL_Control_CAP
#
#                                                  scATAC_counts:pycisTopic_leiden_10_0.6  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP                                       2
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP                                       1
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP                                       0
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP                                       1
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP                                       0
# ...                                                                                 ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP                                       1
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP                                       1
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP                                       1
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP                                       0
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP                                       2
#
#                                                  scATAC_counts:pycisTopic_leiden_10_1.2  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP                                       1
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP                                       0
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP                                       5
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP                                       0
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP                                       8
# ...                                                                                 ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP                                       0
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP                                       0
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP                                       4
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP                                       3
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP                                      11
#
#                                                  scATAC_counts:pycisTopic_leiden_10_3
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP                                    26
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP                                     5
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP                                     2
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP                                     4
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP                                     3
# ...                                                                               ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP                                     4
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP                                    15
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP                                     6
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP                                     9
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP                                    29
#
# [890 rows x 231 columns]

# %%
from scenicplus.scenicplus_class import mudata_to_scenicplus
scplus_obj = mudata_to_scenicplus(
    mdata = scplus_mdata
)
import pickle
pickle.dump(
    scplus_obj,
    open(os.path.join(scplus_outdir, "scplus_obj_old.pkl"), "wb")
)

# %%
scplus_obj.metadata_cell
# Out:
#                                                     orig.ident  nCount_RNA  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP  D253_Multiome      3593.0
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP  D253_Multiome      1667.0
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP  D253_Multiome      3320.0
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP  D253_Multiome      2636.0
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP  D253_Multiome      1997.0
# ...                                                        ...         ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP  D253_Multiome      1138.0
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP  D253_Multiome      3884.0
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP  D111_Multiome      5251.0
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP  D111_Multiome      2275.0
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP  D111_Multiome      3491.0
#
#                                                  nFeature_RNA  nCount_ATAC  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP          1761       6379.0
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP           971       2676.0
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP          1814       6499.0
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP          1554       2650.0
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP          1094       1866.0
# ...                                                       ...          ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP           739       2652.0
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP          1968       2105.0
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP          1874       6145.0
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP          1398       4891.0
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP          1553       4361.0
#
#                                                  nFeature_ATAC  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP           5599
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP           2479
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP           5639
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP           2457
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP           1689
# ...                                                        ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP           2351
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP           1997
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP           5312
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP           4284
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP           3781
#
#                                                             barcode  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP  GACCTTTGTTGCACGG-1
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP  TGAGCACGTGCGCGTA-1
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP  TACCGTTGTGGGTGAA-1
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP  TTGGGTTAGCTCAAAC-1
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP  TAAGTAGCAGCCTGCA-1
# ...                                                             ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP  CCGATGCAGCTCCTAC-1
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP  TGGCTAAGTAATCCCT-1
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP  TGCATCCTCAGGCTAT-1
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP  ACGGTACGTGATTTGG-1
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP  TCATAACCATAAACCT-1
#
#                                                         gex_barcode  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP  GACCTTTGTTGCACGG-1
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP  TGAGCACGTGCGCGTA-1
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP  TACCGTTGTGGGTGAA-1
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP  TTGGGTTAGCTCAAAC-1
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP  TAAGTAGCAGCCTGCA-1
# ...                                                             ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP  CCGATGCAGCTCCTAC-1
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP  TGGCTAAGTAATCCCT-1
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP  TGCATCCTCAGGCTAT-1
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP  ACGGTACGTGATTTGG-1
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP  TCATAACCATAAACCT-1
#
#                                                        atac_barcode  is_cell  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP  GGTGCATCAGGTCAAC-1        1
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP  TAAACCGCAAGTGCCG-1        1
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP  CGGTGTGCAAGTATCG-1        1
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP  GTGTGAGTCGGTAATA-1        1
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP  GTTAACCGTTTCTAAG-1        1
# ...                                                             ...      ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP  GTCGGTTTCTTAGCCA-1        1
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP  CTTCCAGCAGCCTGAG-1        1
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP  CGCTTTAAGGCACGTA-1        1
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP  AGCTAATCACTAAGGC-1        1
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP  GATGGACGTGCACCAC-1        1
#
#                                                  excluded_reason  ...  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP                0  ...
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP                0  ...
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP                0  ...
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP                0  ...
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP                0  ...
# ...                                                          ...  ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP                0  ...
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP                0  ...
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP                0  ...
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP                0  ...
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP                0  ...
#
#                                                  wsnn_res.7  wsnn_res.8  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP          34           1
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP           7          29
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP          29          18
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP           7           9
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP          30          14
# ...                                                     ...         ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP          11          37
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP          18          21
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP          11          37
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP          29          33
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP          32          40
#
#                                                  wsnn_res.9  wsnn_res.10  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP          21           43
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP          31           37
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP          18           20
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP          14           12
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP          15           14
# ...                                                     ...          ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP          19           25
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP          31           37
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP          29           45
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP          18           20
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP          43           18
#
#                                                  Celltype_4  Cluster  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP        CAP1        1
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP        CAP2        8
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP        CAP1        3
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP        CAP2        8
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP        CAP1        4
# ...                                                     ...      ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP        CAP2        8
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP        CAP2        8
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP        CAP2        8
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP        CAP1        3
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP        CAP1        6
#
#                                                  Celltype      Group  \
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP         1  D253_CAP1
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP         2  D253_CAP2
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP         1  D253_CAP1
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP         2  D253_CAP2
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP         1  D253_CAP1
# ...                                                   ...        ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP         2  D253_CAP2
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP         2  D253_CAP2
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP         2  D111_CAP2
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP         1  D111_CAP1
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP         1  D111_CAP1
#
#                                                   celltype       sample_id
# D253_Multiome_GACCTTTGTTGCACGG-1-NL_Control_CAP  D253_CAP1  NL_Control_CAP
# D253_Multiome_TGAGCACGTGCGCGTA-1-NL_Control_CAP  D253_CAP2  NL_Control_CAP
# D253_Multiome_TACCGTTGTGGGTGAA-1-NL_Control_CAP  D253_CAP1  NL_Control_CAP
# D253_Multiome_TTGGGTTAGCTCAAAC-1-NL_Control_CAP  D253_CAP2  NL_Control_CAP
# D253_Multiome_TAAGTAGCAGCCTGCA-1-NL_Control_CAP  D253_CAP1  NL_Control_CAP
# ...                                                    ...             ...
# D253_Multiome_CCGATGCAGCTCCTAC-1-NL_Control_CAP  D253_CAP2  NL_Control_CAP
# D253_Multiome_TGGCTAAGTAATCCCT-1-NL_Control_CAP  D253_CAP2  NL_Control_CAP
# D111_Multiome_TGCATCCTCAGGCTAT-1-NL_Control_CAP  D111_CAP2  NL_Control_CAP
# D111_Multiome_ACGGTACGTGATTTGG-1-NL_Control_CAP  D111_CAP1  NL_Control_CAP
# D111_Multiome_TCATAACCATAAACCT-1-NL_Control_CAP  D111_CAP1  NL_Control_CAP
#
# [890 rows x 104 columns]
